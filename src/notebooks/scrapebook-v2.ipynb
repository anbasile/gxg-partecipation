# %%
import numpy as np
import pandas as pd
import xmltodict
import glob
import re
from os.path import basename, splitext
import pickle

import sys
sys.path.append('../')

from labov import datasets, classifier, evaluation
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.utils import shuffle
# Out:
# /root/.local/share/virtualenvs/src-euU5pS56/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def read_data(files):
    df = {}
    for genre_file in files:
        with open(genre_file) as f:
            tmp = f.read().split('</doc>')
            name = splitext(basename(genre_file))[0]
            df[name] = tmp
            del tmp
    tmp = []
    for name, corpus in df.items():
        i = 0
        for item in corpus:
            m = re.search('<doc id="[0-9]+" genre="[a-zA-Z]+" gender="[M|F|?]">', item)
            if m is not None:
                i += 1
                tmp.append((m.group(0), item))
        assert i==len(corpus)-1
    del df
    df = pd.DataFrame(tmp)

    df.rename(columns={0:'meta', 1:'text'}, inplace=True)
    df['gender'] = df.iloc[:,0].str.extract(r'(M|F)')
    df['genre'] = df.iloc[:,0].str.extract(r'(twitter|youtube|diary|journalism|children)')
    df['docid'] = df.iloc[:,0].str.extract(r'([0-9]+)')
    df.sample(5)
    
    for idx, row in df.iterrows():
        row.text = row.text.replace(row.meta, '').strip()
    
    df.to_json('../../Data/gxg.json', orient='records', lines=True)
    pd.read_json('../../Data/gxg.json', lines=True).sample(5)
    return df

def train_model(df):
    x, y = shuffle(df.text, df.gender, random_state=42)
    cls = classifier.ngram.fit(x, y)
    return cls

# %%
def run_and_write(train_file, test_file, category, setting):
    train_data = read_data([train_file])
    print(train_data.sample(5))
    test_data = read_data([test_file])
    print(test_data.sample(5))
    
    model = train_model(train_data)
    
    with open("{} {}.pickle".format(category, setting), "wb") as f:
        pickle.dump(model, f)
    
    y_pred = cross_val_predict(model, train_data.text, train_data.gender, cv=10, n_jobs=-1)
    print("done!")
    print(evaluation.run(train_data.gender, y_pred))
    preds = model.predict(test_data.text)
    results = zip(test_data.docid, preds)
    result_string = '\n'.join(['{}\t{}'.format(docid, pred) for docid, pred in results])
    fname = "CapetownMilanoTirana_{}_{}_1".format(setting, category)
    with open(fname, "w") as f:
        f.write(result_string)

# %%
# %%time
# IN setting
training_data = glob.glob('../../Data/Training/*')
test_data = glob.glob('../../Data/Test/*')
categories = ["CH", "JO", "TW", "YT", "DI"]

for i in range(5):
    train_file = training_data[i]
    test_file = test_data[i]
    category = categories[i]
    print("training on {}, testing on {}, category {}".format(train_file, test_file, category))
    
    run_and_write(train_file, test_file, category, "IN")
# Out:
# training on ../../Data/Training/GxG_Children.txt, testing on ../../Data/Test/GxG_Children.txt, category CH
#                                            meta  \
# 128  <doc id="129" genre="children" gender="F">
# 118  <doc id="119" genre="children" gender="F">
# 44    <doc id="45" genre="children" gender="M">
# 194  <doc id="195" genre="children" gender="M">
# 109  <doc id="110" genre="children" gender="F">
#
#                                                   text gender     genre docid
# 128  Cosa rappresenta per te la lettura di un bel l...      F  children   129
# 118  Ciao, vorrei dire buongiorno ma sarebbe ipocri...      F  children   119
# 44   Il fatto che mi ha colpito di più è quando ho ...      M  children    45
# 194  Ognuno entra in quotidiano contatto con altre ...      M  children   195
# 109  Il film parla di un giovane irlandese di nome ...      F  children   110
#                                            meta  \
# 134  <doc id="135" genre="children" gender="?">
# 152  <doc id="153" genre="children" gender="?">
# 156  <doc id="157" genre="children" gender="?">
# 146  <doc id="147" genre="children" gender="?">
# 26    <doc id="27" genre="children" gender="?">
#
#                                                   text gender     genre docid
# 134  Caro amico,\nti devo confessare che io non son...    NaN  children   135
# 152  Caro ragazzo. \t\nCome sicuramente ti avranno ...    NaN  children   153
# 156  Ciao Armando, nella scorsa e-mail mi hai doman...    NaN  children   157
# 146  Caro federico,\nti scrivo questa lettera per d...    NaN  children   147
# 26   Cara Marta,\nho saputo che l’anno prossimo ver...    NaN  children    27
# done!
# 0.525
#              precision    recall  f1-score   support
#
#           F       0.52      0.56      0.54       100
#           M       0.53      0.49      0.51       100
#
# avg / total       0.53      0.53      0.52       200
#
# [[56 44]
#  [51 49]]
# 0
# training on ../../Data/Training/GxG_Twitter.txt, testing on ../../Data/Test/GxG_Twitter.txt, category JO
#                                             meta  \
# 3694  <doc id="7178" genre="twitter" gender="F">
# 4570   <doc id="483" genre="twitter" gender="M">
# 3280  <doc id="2475" genre="twitter" gender="M">
# 5179  <doc id="4629" genre="twitter" gender="F">
# 4981   <doc id="855" genre="twitter" gender="M">
#
#                                                    text gender    genre docid
# 3694  Si ma sai chi sono Gigia — Essi https:// l.ask...      F  twitter  7178
# 4570  Se avessimo voluto emigrare lo avremmo giá fat...      M  twitter   483
# 3280  LA LIBERTA' E CAPACITA' INDIVIDUALE E LA "SOAV...      M  twitter  2475
# 5179  Un uomo deve sapersi distinguere dai maschi. S...      F  twitter  4629
# 4981  Particolare come la stampa estera noti la magg...      M  twitter   855
#                                              meta  \
# 4119  <doc id="12273" genre="twitter" gender="?">
# 3748  <doc id="10822" genre="twitter" gender="?">
# 2739  <doc id="18945" genre="twitter" gender="?">
# 4753  <doc id="27760" genre="twitter" gender="?">
# 556    <doc id="9242" genre="twitter" gender="?">
#
#                                                    text gender    genre  docid
# 4119  Ho sognato che biscottino mi vomitava addosso ...    NaN  twitter  12273
# 3748  @bezker1 @PeroMatteo @Wu_Ming_Foundt La realtà...    NaN  twitter  10822
# 2739  "Tutti evidentemente erano dei disgraziati ma ...    NaN  twitter  18945
# 4753  Potremmo esser vs figli. Abbiamo 30anni, abbia...    NaN  twitter  27760
# 556   @AndriCo86 allora non ti consiglio di venire n...    NaN  twitter   9242
# done!
# 0.7366666666666667
#              precision    recall  f1-score   support
#
#           F       0.76      0.70      0.73      3000
#           M       0.72      0.78      0.75      3000
#
# avg / total       0.74      0.74      0.74      6000
#
# [[2091  909]
#  [ 671 2329]]
# 0
# training on ../../Data/Training/GxG_Diary.txt, testing on ../../Data/Test/GxG_Diary.txt, category TW
#                                         meta  \
# 29    <doc id="30" genre="diary" gender="M">
# 90    <doc id="91" genre="diary" gender="M">
# 117  <doc id="118" genre="diary" gender="F">
# 26    <doc id="27" genre="diary" gender="M">
# 125  <doc id="126" genre="diary" gender="F">
#
#                                                   text gender  genre docid
# 29   30.11.2000\nRileggendo questo quaderno, trovo ...      M  diary    30
# 90   Lo sciopero si propagò in altri paesi mano man...      M  diary    91
# 117  Venerdì 16 giugno 1978\nOre 14 circa. Solita i...      F  diary   118
# 26   27.06.1956\nMerano\nAll'inizio dell'anno mi er...      M  diary    27
# 125  Sabato 10 giugno 1978\nOre 11,30. Sono qui. Ho...      F  diary   126
#                                       meta  \
# 16  <doc id="17" genre="diary" gender="?">
# 63  <doc id="64" genre="diary" gender="?">
# 34  <doc id="35" genre="diary" gender="?">
# 56  <doc id="57" genre="diary" gender="?">
# 10  <doc id="11" genre="diary" gender="?">
#
#                                                  text gender  genre docid
# 16  29-10-17\nNon c’è più speranza, i chiodi tedes...    NaN  diary    17
# 63  Salomon Islands, Ottobre 1981\nMarco e Roberto...    NaN  diary    64
# 34  Buenos Aires, 8 maggio 1928 \nIeri e oggi ho p...    NaN  diary    35
# 56  Parigi, 10 maggio 1926\nUn’ora tra i figurinai...    NaN  diary    57
# 10  25 luglio, sabato\nLo stato delle Isole Salomo...    NaN  diary    11
# done!
# 0.705
#              precision    recall  f1-score   support
#
#           F       0.73      0.66      0.69       100
#           M       0.69      0.75      0.72       100
#
# avg / total       0.71      0.70      0.70       200
#
# [[66 34]
#  [25 75]]
# 0
# training on ../../Data/Training/GxG_Journalism.txt, testing on ../../Data/Test/GxG_Journalism.txt, category YT
#                                            meta  \
# 86  <doc id="87" genre="journalism" gender="M">
# 4    <doc id="5" genre="journalism" gender="M">
# 83  <doc id="84" genre="journalism" gender="M">
# 2    <doc id="3" genre="journalism" gender="M">
# 91  <doc id="92" genre="journalism" gender="M">
#
#                                                  text gender       genre docid
# 86  Strage di Capodanno a Milano assassinati il vi...      M  journalism    87
# 4   Troppe ore sui tablet voti bassi in matematica...      M  journalism     5
# 83  Sgomberano la casbah ma i violenti sono fuggit...      M  journalism    84
# 2   "Vietato tagliare il sostegno ai ragazzi disab...      M  journalism     3
# 91  Arriva il primo «resort» spaziale \nCosterà 80...      M  journalism    92
#                                              meta  \
# 119  <doc id="120" genre="journalism" gender="?">
# 76    <doc id="77" genre="journalism" gender="?">
# 136  <doc id="137" genre="journalism" gender="?">
# 130  <doc id="131" genre="journalism" gender="?">
# 88    <doc id="89" genre="journalism" gender="?">
#
#                                                   text gender       genre  \
# 119  Nella rosa ampia Pastore e Nzonzi potranno bri...    NaN  journalism
# 76   L'OBIETTIVO è quello di dare supporto concreto...    NaN  journalism
# 136  Quel Tg1 delle verità rovesciate e sotto accus...    NaN  journalism
# 130  Perché il commercio è la piaga dell'arte\nRoge...    NaN  journalism
# 88   LUOGHI SOSPESI NEL TRENO CHE PARTE\nLa piazza ...    NaN  journalism
#
#     docid
# 119   120
# 76     77
# 136   137
# 130   131
# 88     89
# done!
# 0.615
#              precision    recall  f1-score   support
#
#           F       0.61      0.66      0.63       100
#           M       0.63      0.57      0.60       100
#
# avg / total       0.62      0.61      0.61       200
#
# [[66 34]
#  [43 57]]
# 0
# training on ../../Data/Training/GxG_YouTube.txt, testing on ../../Data/Test/GxG_YouTube.txt, category DI
#                                             meta  \
# 246   <doc id="6504" genre="youtube" gender="M">
# 1972  <doc id="1881" genre="youtube" gender="M">
# 684   <doc id="5947" genre="youtube" gender="M">
# 78    <doc id="6258" genre="youtube" gender="M">
# 1412  <doc id="1941" genre="youtube" gender="F">
#
#                                                    text gender    genre docid
# 246                           crozza è sempre il meglio      M  youtube  6504
# 1972  Coraggioso,tanto coraggioso. Perché coi tempi ...      M  youtube  1881
# 684   Laura Boldrini ha troppa classe per stare sedu...      M  youtube  5947
# 78                                        Che farsa.!!!      M  youtube  6258
# 1412  Unico ,grandeeeeee.\nC' e' niente da aggiungere .      F  youtube  1941
#                                             meta  \
# 444   <doc id="5657" genre="youtube" gender="?">
# 621   <doc id="1750" genre="youtube" gender="?">
# 660   <doc id="6279" genre="youtube" gender="?">
# 4368  <doc id="3125" genre="youtube" gender="?">
# 4113  <doc id="4373" genre="youtube" gender="?">
#
#                                                    text gender    genre docid
# 444   Succede tutto per una ragione, al mondo e... l...    NaN  youtube  5657
# 621             Spolliciate per farlo venire a Cagliari    NaN  youtube  1750
# 660            fede completamente biondo a me non piace    NaN  youtube  6279
# 4368           Le malattie sono comprese nel prezzo ???    NaN  youtube  3125
# 4113                 A me piace un sacco questa Canzone    NaN  youtube  4373
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# CPU times: user 57.4 s, sys: 1.28 s, total: 58.7 s
# Wall time: 3min 35s

# %%
# %%time

# OUT setting
training_data = glob.glob('../../Data/Training/*')
test_data = glob.glob('../../Data/Test/*')
categories = ["CH", "JO", "TW", "YT", "DI"]

for i in range(5):
    train_d = training_data[:]
    del train_d[i]
    print(train_d)
    test_file = test_data[i]
    category = categories[i]
    print("training on {}, testing on {}, category {}".format(train_d, test_file, category))
    
    run_and_write(train_file, test_file, category, "OUT")
# Out:
# ['../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt']
# training on ['../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt'], testing on ../../Data/Test/GxG_Children.txt, category CH
#                                             meta  \
# 3685  <doc id="4953" genre="youtube" gender="M">
# 3046   <doc id="820" genre="youtube" gender="M">
# 4263  <doc id="6827" genre="youtube" gender="M">
# 1573   <doc id="891" genre="youtube" gender="F">
# 1109  <doc id="3338" genre="youtube" gender="M">
#
#                                                    text gender    genre docid
# 3685      zoccola perche' non l'hai detto in parlamento      M  youtube  4953
# 3046  Vabbè non mi sembra qs granché, già visto e se...      M  youtube   820
# 4263                almeno bersani è un po' autocritico      M  youtube  6827
# 1573                          Sei il numero 1, Fiorello      F  youtube   891
# 1109  davvero una spiegazione fantastica questa raga...      M  youtube  3338
#                                            meta  \
# 192  <doc id="193" genre="children" gender="?">
# 66    <doc id="67" genre="children" gender="?">
# 55    <doc id="56" genre="children" gender="?">
# 123  <doc id="124" genre="children" gender="?">
# 72    <doc id="73" genre="children" gender="?">
#
#                                                   text gender     genre docid
# 192  Roma, 13 Maggio 2014-05-18 \nCaro Gianni,\nho ...    NaN  children   193
# 66   Caro Enrico,\nio alle elementari non facevo co...    NaN  children    67
# 55   Caro Andrea, l’inizio della scuola è duro per ...    NaN  children    56
# 123  Caro amico della quarta, la quinta sarà un po’...    NaN  children   124
# 72   Caro Gigi,                                    ...    NaN  children    73
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt']
# training on ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt'], testing on ../../Data/Test/GxG_Twitter.txt, category JO
#                                              meta  \
# 4074   <doc id="1426" genre="youtube" gender="M">
# 1126   <doc id="8522" genre="youtube" gender="M">
# 1594   <doc id="9884" genre="youtube" gender="M">
# 4206   <doc id="1236" genre="youtube" gender="M">
# 1154  <doc id="10091" genre="youtube" gender="F">
#
#                                                    text gender    genre  docid
# 4074  La solita propaganda di regime. Gli attori son...      M  youtube   1426
# 1126                                    BELLISSIMO!!!!!      M  youtube   8522
# 1594                           epico l incontro con sio      M  youtube   9884
# 4206                                      Grazie Favino      M  youtube   1236
# 1154                                   bellissimo amore      F  youtube  10091
#                                              meta  \
# 4573  <doc id="15694" genre="twitter" gender="?">
# 3451  <doc id="14615" genre="twitter" gender="?">
# 3108  <doc id="27786" genre="twitter" gender="?">
# 1495   <doc id="9850" genre="twitter" gender="?">
# 1781  <doc id="13058" genre="twitter" gender="?">
#
#                                                    text gender    genre  docid
# 4573  Twitter è diventato una dipendenza. Sta cosa n...    NaN  twitter  15694
# 3451  @LauraPausini In questo momento ti ho invidiat...    NaN  twitter  14615
# 3108  @_McNella sai che non mi ispira per niente ? L...    NaN  twitter  27786
# 1495  L'emozione grande di condurre per il secondo a...    NaN  twitter   9850
# 1781            @FurioGarbagnati Stavo per googlare :-)    NaN  twitter  13058
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt']
# training on ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Journalism.txt', '../../Data/Training/GxG_YouTube.txt'], testing on ../../Data/Test/GxG_Diary.txt, category TW
#                                             meta  \
# 4293  <doc id="1793" genre="youtube" gender="F">
# 4134   <doc id="886" genre="youtube" gender="F">
# 2827  <doc id="6115" genre="youtube" gender="M">
# 1662  <doc id="9240" genre="youtube" gender="M">
# 2105   <doc id="813" genre="youtube" gender="F">
#
#                                                    text gender    genre docid
# 4293  Non ci sono parole, ha fatto qualcosa che tocc...      F  youtube  1793
# 4134           non ce n'e' per nessuno.......number one      F  youtube   886
# 2827                Questo Governo ha Rovinato l'Italia      M  youtube  6115
# 1662  ma voi quando siete in Giappone quale lingua p...      M  youtube  9240
# 2105  che pena! degno del Festival. Lo zombie sullo ...      F  youtube   813
#                                       meta  \
# 39  <doc id="40" genre="diary" gender="?">
# 34  <doc id="35" genre="diary" gender="?">
# 58  <doc id="59" genre="diary" gender="?">
# 25  <doc id="26" genre="diary" gender="?">
# 27  <doc id="28" genre="diary" gender="?">
#
#                                                  text gender  genre docid
# 39  Dopo 8 giorni dal mio nuovo soggiorno il 27.8....    NaN  diary    40
# 34  Buenos Aires, 8 maggio 1928 \nIeri e oggi ho p...    NaN  diary    35
# 58  Partita da Gorizia il 18.6.915 per Trieste ove...    NaN  diary    59
# 25  A Udine ordinarono di recarci al comando di ta...    NaN  diary    26
# 27  Abitai per 4 giorni l'albergo principale Ritze...    NaN  diary    28
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_YouTube.txt']
# training on ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_YouTube.txt'], testing on ../../Data/Test/GxG_Journalism.txt, category YT
#                                             meta  \
# 3973  <doc id="8664" genre="youtube" gender="F">
# 3162  <doc id="3283" genre="youtube" gender="F">
# 2123  <doc id="7476" genre="youtube" gender="F">
# 4073  <doc id="7075" genre="youtube" gender="F">
# 3992  <doc id="4697" genre="youtube" gender="M">
#
#                                                    text gender    genre docid
# 3973                                             ☺🌞❤🙆🚲👍      F  youtube  8664
# 3162  Ho letto molti commenti che; o irridono o cerc...      F  youtube  3283
# 2123  sono una persona che non piange mai, ma questo...      F  youtube  7476
# 4073  "Puffo e terroncino" ahahaha ogni volta muoio ...      F  youtube  7075
# 3992  "Dietro quelli della lega c'è casa pound" bell...      M  youtube  4697
#                                            meta  \
# 57  <doc id="58" genre="journalism" gender="?">
# 21  <doc id="22" genre="journalism" gender="?">
# 58  <doc id="59" genre="journalism" gender="?">
# 3    <doc id="4" genre="journalism" gender="?">
# 59  <doc id="60" genre="journalism" gender="?">
#
#                                                  text gender       genre docid
# 57  IL CORAGGIO DI ALZARE LA VOCE\nSCENDO, cambio ...    NaN  journalism    58
# 21  Bill Viola e l' acqua l' arte incontra il cosm...    NaN  journalism    22
# 58  ILLUSIONI VIETATE È MEGLIO PENSARE GIÀ AL DOMA...    NaN  journalism    59
# 3   "Mi guarì contro ogni previsione Decisi di dar...    NaN  journalism     4
# 59  IN SILENZIO DAVANTI AL CRISTO VELATO\nProvo an...    NaN  journalism    60
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt']
# training on ['../../Data/Training/GxG_Children.txt', '../../Data/Training/GxG_Twitter.txt', '../../Data/Training/GxG_Diary.txt', '../../Data/Training/GxG_Journalism.txt'], testing on ../../Data/Test/GxG_YouTube.txt, category DI
#                                             meta  \
# 1514  <doc id="1634" genre="youtube" gender="F">
# 2124  <doc id="4647" genre="youtube" gender="M">
# 76    <doc id="4083" genre="youtube" gender="F">
# 1469  <doc id="9919" genre="youtube" gender="M">
# 1616  <doc id="2392" genre="youtube" gender="M">
#
#                                                    text gender    genre docid
# 1514  Veramente emozionante. Ma come si fa a rimaner...      F  youtube  1634
# 2124  io col tempo ho imparato leggendo quà e là, ch...      M  youtube  4647
# 76        la tarantola in italia ma ditene un altra....      F  youtube  4083
# 1469                                      Sei un grande      M  youtube  9919
# 1616  ragazzi   questo video è interessante ma non t...      M  youtube  2392
#                                             meta  \
# 2255  <doc id="7326" genre="youtube" gender="?">
# 4205  <doc id="5584" genre="youtube" gender="?">
# 239   <doc id="6604" genre="youtube" gender="?">
# 2431  <doc id="3311" genre="youtube" gender="?">
# 607   <doc id="1862" genre="youtube" gender="?">
#
#                                                    text gender    genre docid
# 2255              Questa canzone descrive la mia estate    NaN  youtube  7326
# 4205  BELLISSIMA FAVOLOSA FANTASTICA UNA CANZONE UNI...    NaN  youtube  5584
# 239             Annalisa è semplicemente meravigliosa 😍    NaN  youtube  6604
# 2431                                    Annalisa t.v.b.    NaN  youtube  3311
# 607                                   canzone a 3:29???    NaN  youtube  1862
# done!
# 0.6154545454545455
#              precision    recall  f1-score   support
#
#           F       0.61      0.62      0.62      2200
#           M       0.62      0.61      0.61      2200
#
# avg / total       0.62      0.62      0.62      4400
#
# [[1362  838]
#  [ 854 1346]]
# 0
# CPU times: user 1min 2s, sys: 1.29 s, total: 1min 4s
# Wall time: 3min 44s
