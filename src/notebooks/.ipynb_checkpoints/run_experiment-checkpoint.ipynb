# %% [markdown]
# # Experiments

# %%
import numpy as np
import pandas as pd
import sys
import mysql.connector
# Add the ptdraft folder path to the sys.path list
sys.path.append('../')
from labov import datasets, classifier, evaluation
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.utils import shuffle
import spacy
nlp = spacy.load('en', disable=['parser'])

# %%
df = pd.read_json('../../data/labov01_b.json', lines=True)
df.sample(5)
# Out:
#                                                     text  \
# 7382   If I can give this place a zero I would!!!! Ma...
# 54101  Dinner has always been excellent so no complai...
# 28654  Best Margs EVER!!! Seriously. Cheap beer, grea...
# 33259  Is it just me or are a lot of the restaurants ...
# 16371  I really love how clean it is here, they use f...
#
#                       user_id  y
# 7382   4_XXK2SawW_gsdq9dF33Xg  1
# 54101  R4bOjG3V6UAD8w56_CjEJA  2
# 28654  gHQtfx1BP13ob8qTmm9hXQ  1
# 33259  Iec0Qou1MH6zk7I4y_4nrA  2
# 16371  Bd0CpWVJbYCl0iI4gLqkuQ  2

# %%
def tag(text):
    tags = ' '.join((w.pos_ for w in nlp(text)))
    return tags

xs = shuffle(df.text, n_samples=10)

# %%
smallest = df.y.value_counts().min()
tmp = []
for label in set(df.y):
    tmp.append(df[df.y == label].sample(smallest, random_state=42))
df_balanced = pd.concat(tmp)

# %% [markdown]
# ## Training and CV on balanced dataset

# %% [markdown]
# ### Lexicalized model

# %%
# %%time
x, y = shuffle(df_balanced.text, df_balanced.y, random_state=42)
# x = [tag(x) for x in xs]
print("running the baseline...")
random = cross_val_score(classifier.random, x, y, cv=5, n_jobs=-1)
print("done!")
print("Accuracy: %0.2f (+/- %0.2f)" % (random.mean(), random.std() * 2))

print("fitting model...")
model_lexi = classifier.simple.fit(x, y)
y_pred = cross_val_predict(classifier.simple, x, y, cv=10, n_jobs=-1)
print("done!")
# print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print(evaluation.run(y_pred, y))
# Out:
# running the baseline...
# done!
# Accuracy: 0.24 (+/- 0.05)
# fitting model...
# done!
# 0.4765625
#              precision    recall  f1-score   support
#
#           1       0.55      0.51      0.53       139
#           2       0.34      0.39      0.36       114
#           3       0.46      0.48      0.47       124
#           4       0.55      0.52      0.53       135
#
# avg / total       0.48      0.48      0.48       512
#
# [[71 40 13 15]
#  [31 44 27 12]
#  [12 22 59 31]
#  [14 22 29 70]]
# 0
# CPU times: user 906 ms, sys: 114 ms, total: 1.02 s
# Wall time: 4.97 s

# %% [markdown]
# ### Bleaching

# %%
from collections import Counter
wordCount = Counter(df_balanced.text.str.cat(sep='\n').split())

def bleach_0(text:str, word_dic=None)->str:
    shapes = ' '.join([w.shape_ for w in nlp(text)])
    return shapes

def bleach_1(text:str, word_dic=None)->str:
    bleached = ' '.join(['_'.join((w.shape_, 
                                   str(len(w)))) for w in nlp(text)])
    return bleached

def bleach_2(text:str, word_dic=None)->str:
    bleached = ' '.join(['_'.join((w.shape_, 
                                   str(len(w)),
                                   w.pos_)) for w in nlp(text)])
    return bleached


def bleach_3(text:str, word_dic=None)->str:
    bleached = ' '.join(['_'.join((w.shape_, 
                                   str(len(w)),
                                   str(w.is_alpha),
                                   approximate(w.text),
                                   str(wordCount[w.text]))) for w in nlp(text)])
    return bleached

def bleach_4(text:str, word_dic=None)->str:
    bleached = ' '.join(['_'.join((w.shape_, 
                                   str(len(w)),
                                   w.pos_,
                                   str(w.is_alpha))) for w in nlp(text)])
    return bleached

def lexibleach_0(text:str, word_dic=None)->str:
    bleached = ' '.join(['_'.join((w.shape_, 
                                   str(len(w)),
                                   w.pos_,
                                   w.text,
                                   str(w.is_alpha))) for w in nlp(text)])
    return bleached

def lexionly(text:str, word_dic=None)->str:
    bleached = ' '.join([''.join((w.text)) for w in nlp(text)])
    return bleached

import re

def approximate(word):
    vowels = '[aeiou]'
    consonants = '[^aeiou]'
    others = '[^a-Z]' # TODO
    tmp = re.sub(consonants, 'C', word.replace(" ",""))
    result = re.sub(vowels,'V', tmp)
    return result

# %%
# %%time
x, y = shuffle(df_balanced.text.apply(lambda x: bleach_3(x)), 
               df_balanced.y, 
               random_state=42)

print("fitting model...")
model = classifier.simple.fit(x, y)
y_pred = cross_val_predict(classifier.simple, x, y, cv=10, n_jobs=-1)
print("done")
print(evaluation.run(y, y_pred))
# Out:
# fitting model...
# done
# 0.443359375
#              precision    recall  f1-score   support
#
#           1       0.44      0.49      0.47       128
#           2       0.32      0.30      0.31       128
#           3       0.46      0.45      0.45       128
#           4       0.53      0.54      0.53       128
#
# avg / total       0.44      0.44      0.44       512
#
# [[63 41 12 12]
#  [46 38 26 18]
#  [15 25 57 31]
#  [18 13 28 69]]
# 0
# CPU times: user 37.1 s, sys: 31.1 s, total: 1min 8s
# Wall time: 22.3 s

# %% [markdown]
# ### Train bleached model on all dataset

# %%
nonen = pd.read_json('../../data/non-english-author.json', lines=True)
allen = pd.concat([df[['text', 'y']], nonen])

# %%
allen_min = allen.y.value_counts().min()

allen_tmp = []
for label in set(allen.y):
    allen_tmp.append(allen[allen.y == label].sample(allen_min, random_state=42))
allen_corpus = pd.concat(allen_tmp)

# %%
print("fitting model...")
x = allen_corpus.text.apply(lambda x: bleach_3(x))
y = allen_corpus.y
y_pred = cross_val_predict(classifier.ngram, x, y, cv=10, n_jobs=-1)
print("done")
print(evaluation.run(y, y_pred))
# Out:
# fitting model...
# done
# 0.4836409395973154
#              precision    recall  f1-score   support
#
#           1       0.50      0.51      0.50       596
#           2       0.43      0.42      0.43       596
#           3       0.45      0.43      0.44       596
#           4       0.54      0.58      0.56       596
#
# avg / total       0.48      0.48      0.48      2384
#
# [[302 193  51  50]
#  [210 253  87  46]
#  [ 55  94 255 192]
#  [ 35  45 173 343]]
# 0

# %% [markdown]
# ## Testing

# %%
# %%time
# here we test on the rest of the dataset
test = pd.concat([df, df_balanced]).drop_duplicates(keep=False)
test_smallest = test.y.value_counts().min()

test_tmp = []
for label in set(test.y):
    test_tmp.append(test[test.y == label].sample(test_smallest, random_state=42))
test_corpus = pd.concat(test_tmp)

print(test_corpus.shape)

y_test = model.predict(test_corpus.text.apply(lambda x: bleach_3(x)))

print(classification_report(test_corpus.y, y_test))
print(accuracy_score(test_corpus.y, y_test))
# Out:
# (5181, 3)
#              precision    recall  f1-score   support
#
#           1       0.52      0.55      0.53      1727
#           2       0.41      0.30      0.35      1727
#           3       0.65      0.50      0.57      1727
#           4       0.00      0.00      0.00         0
#
# avg / total       0.53      0.45      0.48      5181
#
# 0.45010615711252655
# CPU times: user 7min 7s, sys: 5min 51s, total: 12min 58s
# Wall time: 3min 49s
# /home/me/.local/share/virtualenvs/src-kGqpUVT-/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# ## Multi-lingual testing

# %%
# %%time
# testing the non lexicalized model
multilang = pd.read_json('../../data/non-english-author.json', lines=True)
multi_test_smallest = multilang.y.value_counts().min()

multi_tmp = []
for label in set(multilang.y):
    multi_tmp.append(multilang[multilang.y == label].sample(multi_test_smallest, random_state=42))
multi_corpus = pd.concat(multi_tmp)

print(multi_corpus.shape)

y_test = model.predict(multi_corpus.text.apply(lambda x: bleach_3(x)))

print(classification_report(multi_corpus.y, y_test))
print(accuracy_score(multi_corpus.y, y_test))
# Out:
# (1872, 2)
#              precision    recall  f1-score   support
#
#           1       0.55      0.07      0.13       468
#           2       0.26      0.19      0.22       468
#           3       0.27      0.75      0.40       468
#           4       0.34      0.13      0.18       468
#
# avg / total       0.36      0.29      0.24      1872
#
# 0.28739316239316237
# CPU times: user 1min 34s, sys: 1min 21s, total: 2min 56s
# Wall time: 50.6 s

# %%
# %%time
# testing the lexicalized model
multilang = pd.read_json('../../data/non-english-author.json', lines=True)
multi_test_smallest = multilang.y.value_counts().min()

multi_tmp = []
for label in set(multilang.y):
    multi_tmp.append(multilang[multilang.y == label].sample(multi_test_smallest, random_state=42))
multi_corpus = pd.concat(multi_tmp)

print(multi_corpus.shape)

y_test = model_lexi.predict(multi_corpus.text)

print(classification_report(multi_corpus.y, y_test))
print(accuracy_score(multi_corpus.y, y_test))
# Out:
# (1872, 2)
#              precision    recall  f1-score   support
#
#           1       0.30      0.01      0.02       468
#           2       0.00      0.00      0.00       468
#           3       0.25      0.15      0.19       468
#           4       0.26      0.87      0.40       468
#
# avg / total       0.20      0.26      0.15      1872
#
# 0.25801282051282054
# CPU times: user 2.5 s, sys: 776 µs, total: 2.5 s
# Wall time: 2.5 s

# %% [markdown]
# ## Feature analysis

# %%
model.named_steps['features'].get_feature_names()
# Out:
# ['X',
#  'X X',
#  'X X_12_False_CCVCCVCCCCCC_1',
#  'X X_3_False_CCC_1',
#  'X Xx_5_False_CCCCC_1',
#  'X Xxxxx_9_False_CCCCVCCVC_1',
#  'X Xxxxx_9_False_CCCCVCVVC_1',
#  'X _2_False_CC_1',
#  'X _4_False_CCCC_0',
#  'X _4_False_CCCC_1',
#  'X _6_False_CCCCCC_1',
#  'X dd_4_False_CCCC_0',
#  'X x_14_False_CVCCVCVCCCCCCC_1',
#  'X x_3_False_CCC_89',
#  'X x_7_False_CVCCCCC_1',
#  'X x_8_False_CVCCCCCC_1',
#  'X xx_10_False_CVVCCCCCCV_1',
#  'X xx_10_False_VVCCCCCCCV_1',
#  'X xx_11_False_CCCVCCCCCCV_1',
#  'X xx_11_False_CCVCVCCCCCV_1',
#  'X xx_11_False_CCVVCCCCCCV_1',
#  'X xx_12_False_CCVCVCCCCCCV_1',
#  'X xx_14_False_CCCCCCCCCCCCCV_1',
#  'X xx_15_False_CVCVCVVVCCCCCCV_1',
#  'X xx_4_False_CCVV_1',
#  'X xx_5_False_CCCCV_0',
#  'X xxx_5_False_CCCVC_1',
#  'X xxx_5_False_CCCVV_0',
#  'X xxxx_9_False_CCVCVCCVC_0',
#  'XX',
#  'XX X_4_False_CCCC_1',
#  'XX Xx_6_False_CCCCCV_1',
#  'XXX',
#  'XXX X_5_False_CCCCC_1',
#  'XXX X_7_False_CCCCCCC_1',
#  'XXX Xx_7_False_CCCCCCV_1',
#  'XXX Xxxx_9_False_CCCCCCCVV_0',
#  'XXX Xxxxx_11_False_CCCCCCVVCCC_1',
#  'XXXX',
#  'XXXX X',
#  'XXXX X_10_False_CCCCCCCCCC_1',
#  'XXXX X_7_False_CCCCCCC_1',
#  'XXXX Xxx_10_False_CCCCCCCCCV_1',
#  'XXXX Xxx_15_False_CCCCCCCCCCCCCCC_1',
#  'XXXX Xxxxx_13_False_CCCCCCCCCVCCV_1',
#  'XXXX Xxxxx_14_False_CCCCCCCCCCVCCC_1',
#  'XXXX Xxxxx_14_False_CCCCCCCCCCVCVC_1',
#  'XXXX d_10_False_CCCCCCCCCC_1',
#  'XXXX_10_False_CVVCCCCCCC_1',
#  'XXXX_10_False_CVVCCCCCCC_1 XXXX_4_True_CCCC_0',
#  'XXXX_10_True_CCCCCCCCCC_0',
#  'XXXX_10_True_CCCCCCCCCC_0 XXXX_7_True_CCCCCCC_0',
#  'XXXX_10_True_CCCCCCCCCC_0 _1_False_C_12',
#  'XXXX_10_True_CCCCCCCCCC_0 _1_False_C_4',
#  'XXXX_10_True_CCCCCCCCCC_0 _1_False_C_9',
#  'XXXX_10_True_CCCCCCCCCC_1',
#  'XXXX_10_True_CCCCCCCCCC_1 XXXX_5_True_CCCCC_0',
#  'XXXX_10_True_CCCCCCCCCC_1 XXXX_7_True_CCCCCCC_1',
#  'XXXX_10_True_CCCCCCCCCC_1 _1_False_C_12',
#  'XXXX_10_True_CCCCCCCCCC_1 _1_False_C_9',
#  'XXXX_10_True_CCCCCCCCCC_1 xx_2_True_VC_1297',
#  'XXXX_10_True_CCCCCCCCCC_2',
#  'XXXX_10_True_CCCCCCCCCC_2 xx_2_True_CV_366',
#  'XXXX_10_True_CCCCCCCCCC_2 xxxx_5_True_CCVCC_28',
#  'XXXX_11_True_CCCCCCCCCCC_1',
#  'XXXX_11_True_CCCCCCCCCCC_1 xxxx_4_True_CVCC_4',
#  'XXXX_12_False_CCCCCCCCCCCC_0',
#  'XXXX_12_False_CCCCCCCCCCCC_0 XXXX_7_True_CCCCCCC_0',
#  'XXXX_15_False_CVCCCVCVCCCCCCC_1',
#  'XXXX_15_False_CVCCCVCVCCCCCCC_1 X_1_True_C_0',
#  'XXXX_17_True_CCCCCCCCCCCCCCCCC_0',
#  'XXXX_17_True_CCCCCCCCCCCCCCCCC_0 _1_False_C_12',
#  'XXXX_18_False_VCVCVCCCCCCCCCCCCC_0',
#  'XXXX_18_False_VCVCVCCCCCCCCCCCCC_0 _1_False_C_7',
#  'XXXX_21_True_CCCCCCCCCCCCCCCCCCCCC_1',
#  'XXXX_21_True_CCCCCCCCCCCCCCCCCCCCC_1 XXXX_17_True_CCCCCCCCCCCCCCCCC_0',
#  'XXXX_4_True_CCCC_0',
#  'XXXX_4_True_CCCC_0 XXXX_7_True_CCCCCCC_0',
#  'XXXX_4_True_CCCC_0 _1_False_C_12',
#  'XXXX_4_True_CCCC_0 _1_False_C_16',
#  'XXXX_4_True_CCCC_0 _1_False_C_163',
#  'XXXX_4_True_CCCC_0 _1_False_C_4',
#  'XXXX_4_True_CCCC_0 _1_False_C_9',
#  'XXXX_4_True_CCCC_0 xx_2_True_VC_1365',
#  'XXXX_4_True_CCCC_1',
#  'XXXX_4_True_CCCC_1 XXXX_4_True_CCCC_0',
#  'XXXX_4_True_CCCC_1 XXXX_4_True_CCCC_1',
#  'XXXX_4_True_CCCC_1 XXXX_5_True_CCCCC_5',
#  'XXXX_4_True_CCCC_1 XXXX_6_True_CCCCCC_0',
#  'XXXX_4_True_CCCC_1 XXXX_6_True_CCCCCC_1',
#  'XXXX_4_True_CCCC_1 XXXX_7_True_CCCCCCC_0',
#  'XXXX_4_True_CCCC_1 XXX_3_True_CCC_0',
#  'XXXX_4_True_CCCC_1 XXX_3_True_CCC_1',
#  'XXXX_4_True_CCCC_1 XXX_3_True_CCC_13',
#  'XXXX_4_True_CCCC_1 XX_2_True_CC_3',
#  'XXXX_4_True_CCCC_1 XX_2_True_CC_4',
#  'XXXX_4_True_CCCC_1 XX_2_True_CC_5',
#  'XXXX_4_True_CCCC_1 XX_2_True_CC_8',
#  'XXXX_4_True_CCCC_1 X_1_True_C_71',
#  'XXXX_4_True_CCCC_1 Xxxx_4_True_CVCV_1',
#  'XXXX_4_True_CCCC_1 _1_False_C_0',
#  'XXXX_4_True_CCCC_1 _1_False_C_12',
#  'XXXX_4_True_CCCC_1 _1_False_C_16',
#  'XXXX_4_True_CCCC_1 _2_False_CC_0',
#  'XXXX_4_True_CCCC_1 xx_2_True_CC_158',
#  'XXXX_4_True_CCCC_1 xx_2_True_CV_2078',
#  'XXXX_4_True_CCCC_1 xx_2_True_VC_1297',
#  'XXXX_4_True_CCCC_1 xx_2_True_VC_596',
#  'XXXX_4_True_CCCC_1 xxx_3_True_CCV_80',
#  'XXXX_4_True_CCCC_1 xxx_3_True_CVC_1859',
#  'XXXX_4_True_CCCC_1 xxx_3_True_CVV_612',
#  'XXXX_4_True_CCCC_1 xxx_3_True_VCC_3169',
#  'XXXX_4_True_CCCC_1 xxx_3_True_VVC_73',
#  'XXXX_4_True_CCCC_1 xxxx_10_True_CVCCVCCVVC_3',
#  'XXXX_4_True_CCCC_1 xxxx_11_True_VCCVCCCVVCC_0',
#  'XXXX_4_True_CCCC_1 xxxx_4_True_CVCC_709',
#  'XXXX_4_True_CCCC_1 xxxx_4_True_CVVC_8',
#  'XXXX_4_True_CCCC_1 xxxx_5_True_CVCCC_53',
#  'XXXX_4_True_CCCC_1 xxxx_9_True_CVCCVCCVC_10',
#  'XXXX_4_True_CCCC_10',
#  'XXXX_4_True_CCCC_10 XXXX_4_True_CCCC_10',
#  'XXXX_4_True_CCCC_10 XXXX_4_True_CCCC_2',
#  'XXXX_4_True_CCCC_10 xx_2_True_VC_828',
#  'XXXX_4_True_CCCC_10 xxx_3_True_CCV_4090',
#  'XXXX_4_True_CCCC_10 xxxx_4_True_CCVC_577',
#  'XXXX_4_True_CCCC_10 xxxx_7_True_CCVCCCV_11',
#  'XXXX_4_True_CCCC_2',
#  'XXXX_4_True_CCCC_2 XXX',
#  'XXXX_4_True_CCCC_2 XXXX_10_True_CCCCCCCCCC_0',
#  'XXXX_4_True_CCCC_2 XXXX_4_True_CCCC_0',
#  'XXXX_4_True_CCCC_2 XXXX_4_True_CCCC_1',
#  'XXXX_4_True_CCCC_2 XXXX_5_True_CCCCC_1',
#  'XXXX_4_True_CCCC_2 XXX_3_True_CCC_13',
#  'XXXX_4_True_CCCC_2 XX_2_True_CC_2',
#  'XXXX_4_True_CCCC_2 XX_2_True_CC_5',
#  'XXXX_4_True_CCCC_2 XX_2_True_CC_8',
#  'XXXX_4_True_CCCC_2 X_2_False_CC_0',
#  'XXXX_4_True_CCCC_2 Xx_2_True_CV_0',
#  'XXXX_4_True_CCCC_2 Xxxx_4_True_CVCC_4',
#  'XXXX_4_True_CCCC_2 _1_False_C_9',
#  'XXXX_4_True_CCCC_2 xx_2_True_CV_2078',
#  'XXXX_4_True_CCCC_2 xx_2_True_CV_440',
#  'XXXX_4_True_CCCC_2 xx_2_True_VC_1297',
#  'XXXX_4_True_CCCC_2 xxx_3_True_CVV_612',
#  'XXXX_4_True_CCCC_2 xxxx_4_True_CVCC_120',
#  'XXXX_4_True_CCCC_2 xxxx_4_True_CVCC_294',
#  'XXXX_4_True_CCCC_2 xxxx_5_True_CVCVC_6',
#  'XXXX_4_True_CCCC_2 xxxx_7_True_CCVCCVC_1',
#  'XXXX_4_True_CCCC_2 xxxx_7_True_CVCCVCV_6',
#  'XXXX_4_True_CCCC_2 xxxx_8_True_CVCVCVVC_47',
#  'XXXX_4_True_CCCC_2 xxxx_8_True_CVVCCVCC_2',
#  'XXXX_4_True_CCCC_3',
#  'XXXX_4_True_CCCC_3 XXXX_4_True_CCCC_3',
#  'XXXX_4_True_CCCC_3 XXX_3_True_CCC_1',
#  'XXXX_4_True_CCCC_3 _1_False_C_9',
#  'XXXX_4_True_CCCC_3 xx_2_True_VC_1297',
#  'XXXX_4_True_CCCC_3 xxx_3_True_CCV_70',
#  'XXXX_4_True_CCCC_3 xxx_3_True_CVC_1859',
#  'XXXX_4_True_CCCC_3 xxxx_11_True_CVCCVCCVCCV_12',
#  'XXXX_4_True_CCCC_3 xxxx_4_True_CVCV_44',
#  'XXXX_4_True_CCCC_3 xxxx_5_True_CCVVC_43',
#  'XXXX_4_True_CCCC_3 xxxx_7_True_CVCVCVC_6',
#  'XXXX_4_True_CCCC_3 xxxx_8_True_CCVCCVCC_1',
#  'XXXX_4_True_CCCC_3 xxxx_8_True_CVCVCVCV_4',
#  'XXXX_4_True_CCCC_8',
#  'XXXX_4_True_CCCC_8 XXXX_5_True_CCCCC_1',
#  'XXXX_4_True_CCCC_8 Xxxx_4_True_CCVV_20',
#  'XXXX_4_True_CCCC_8 _1_False_C_12',
#  'XXXX_8_True_CCCCCCCC_1 xxx_3_True_CVV_120',
#  'XXXX_8_True_CCCCCCCC_1 xxxx_4_True_CVVC_73',
#  'XXXX_8_True_CCCCCCCC_1 xxxx_5_True_CVCVC_21',
#  'XXXX_8_True_CCCCCCCC_2',
#  'XXXX_8_True_CCCCCCCC_2 XXXX_8_True_CCCCCCCC_2',
#  'XXXX_8_True_CCCCCCCC_2 _1_False_C_9',
#  'XXXX_8_True_CCCCCCCC_2 _2_False_CC_7',
#  'XXXX_8_True_CCCCCCCC_2 xxxx_5_True_CCVCV_404',
#  'XXXX_8_True_CCCCCCCC_2 xxxx_9_True_CCVVCCVCC_46',
#  'XXXX_9_True_CCCCCCCCC_0',
#  'XXXX_9_True_CCCCCCCCC_0 _1_False_C_12',
#  'XXXX_9_True_CCCCCCCCC_0 _1_False_C_9',
#  'XXXX_9_True_CCCCCCCCC_1',
#  'XXXX_9_True_CCCCCCCCC_1 XXXX_4_True_CCCC_0',
#  'XXXX_9_True_CCCCCCCCC_1 XXXX_6_True_CCCCCC_1',
#  'XXXX_9_True_CCCCCCCCC_1 XXXX_7_True_CCCCCCC_0',
#  'XXXX_9_True_CCCCCCCCC_1 XXX_3_True_CCC_13',
#  'XXXX_9_True_CCCCCCCCC_1 _1_False_C_12',
#  'XXXX_9_True_CCCCCCCCC_1 _1_False_C_9',
#  'XXXX_9_True_CCCCCCCCC_1 _1_False__0',
#  'XXXX_9_True_CCCCCCCCC_1 xx_2_True_CV_2078',
#  'XXXX_9_True_CCCCCCCCC_1 xxxx_4_True_CCVC_17',
#  'XXXXxxxx_13_True_CCCCVCCVVCVCC_0',
#  'XXXXxxxx_13_True_CCCCVCCVVCVCC_0 _1_False_C_16',
#  'XXX_10_False_CVCVCCCCCC_1',
#  'XXX_10_False_CVCVCCCCCC_1 xxxx_4_True_CVVC_329',
#  'XXX_12_False_CVCVCCCCCCCC_1',
#  'XXX_12_False_CVCVCCCCCCCC_1 xx_2_True_VC_1297',
#  'XXX_16_False_VCCVCVCVCVCCCCCC_0',
#  'XXX_16_False_VCCVCVCVCVCCCCCC_0 _1_False_C_9',
#  'XXX_3_True_CCC_0',
#  'XXX_3_True_CCC_0 X_2_False_CC_0',
#  'XXX_3_True_CCC_0 _1_False_C_1',
#  'XXX_3_True_CCC_0 _1_False_C_12',
#  'XXX_3_True_CCC_0 _1_False_C_16',
#  'XXX_3_True_CCC_0 _1_False_C_3',
#  'XXX_3_True_CCC_0 _1_False_C_4',
#  'XXX_3_True_CCC_0 _1_False_C_9',
#  'XXX_3_True_CCC_0 _2_False_CC_7',
#  'XXX_3_True_CCC_0 _3_False_CCC_14',
#  'XXX_3_True_CCC_0 x_2_False_CC_0',
#  'XXX_3_True_CCC_1',
#  'XXX_3_True_CCC_1 XXXX_10_True_CCCCCCCCCC_0',
#  'XXX_3_True_CCC_1 XXXX_5_True_CCCCC_1',
#  'XXX_3_True_CCC_1 XXXX_7_True_CCCCCCC_0',
#  'XXX_3_True_CCC_1 XXX_3_True_CCC_0',
#  'XXX_3_True_CCC_1 XX_2_True_CC_1',
#  'XXX_3_True_CCC_1 X_1_True_C_2235',
#  'XXX_3_True_CCC_1 X_1_True_C_71',
#  'XXX_3_True_CCC_1 Xxxx_4_True_CVCC_4',
#  'XXX_3_True_CCC_1 Xxxxx_5_True_CVCVV_1',
#  'XXX_3_True_CCC_1 Xxxxx_8_True_CCVCVCVC_1',
#  'XXX_3_True_CCC_1 _1_False_C_12',
#  'XXX_3_True_CCC_1 _1_False_C_16',
#  'XXX_3_True_CCC_1 _1_False_C_9',
#  'XXX_3_True_CCC_1 xx_2_True_VC_1049',
#  'XXX_3_True_CCC_1 xx_2_True_VC_1297',
#  'XXX_3_True_CCC_1 xx_2_True_VC_231',
#  'XXX_3_True_CCC_1 xxx_3_True_CCV_4090',
#  'XXX_3_True_CCC_1 xxx_3_True_CVC_1859',
#  'XXX_3_True_CCC_1 xxx_3_True_CVC_22',
#  'XXX_3_True_CCC_1 xxx_3_True_CVC_75',
#  'XXX_3_True_CCC_1 xxx_3_True_VCC_3169',
#  'XXX_3_True_CCC_1 xxxx_12_True_VCCCVCVCVCCV_0',
#  'XXX_3_True_CCC_1 xxxx_4_True_CVCC_294',
#  'XXX_3_True_CCC_1 xxxx_5_True_CCVCC_188',
#  'XXX_3_True_CCC_1 xxxx_5_True_CCVCC_2',
#  'XXX_3_True_CCC_1 xxxx_5_True_CCVCC_4',
#  'XXX_3_True_CCC_1 xxxx_5_True_CVCCC_77',
#  'XXX_3_True_CCC_1 xxxx_5_True_CVCVC_1',
#  'XXX_3_True_CCC_1 xxxx_6_True_CCVCVC_11',
#  'XXX_3_True_CCC_1 xxxx_7_True_CVVCVCC_24',
#  'XXX_3_True_CCC_13',
#  'XXX_3_True_CCC_13 XXXX_4_True_CCCC_0',
#  'XXX_3_True_CCC_13 XXXX_4_True_CCCC_1',
#  'XXX_3_True_CCC_13 XXXX_5_True_CCCCC_0',
#  'XXX_3_True_CCC_13 XXXX_5_True_CCCCC_1',
#  'XXX_3_True_CCC_13 XXXX_5_True_CCCCC_2',
#  'XXX_3_True_CCC_13 XXXX_7_True_CCCCCCC_1',
#  'XXX_3_True_CCC_13 Xxxxx_5_True_CVCVC_7',
#  'XXX_3_True_CCC_13 xxxx_4_True_CVCC_69',
#  'XXX_3_True_CCC_13 xxxx_8_True_CVCCVCVC_2',
#  'XXX_3_True_CCC_16',
#  'XXX_3_True_CCC_16 XXXX_4_True_CCCC_2',
#  'XXX_3_True_CCC_16 XXXX_5_True_CCCCC_1',
#  'XXX_3_True_CCC_16 XX_2_True_CC_8',
#  'XXX_3_True_CCC_16 Xxxxx',
#  'XXX_3_True_CCC_16 _1_False_C_16',
#  'XXX_3_True_CCC_16 xx_2_True_CV_207',
#  'XXX_3_True_CCC_16 xxx_3_True_CCV_4090',
#  'XXX_3_True_CCC_16 xxx_3_True_CVV_62',
#  'XXX_3_True_CCC_16 xxxx_4_True_CVCV_57',
#  'XXX_3_True_CCC_16 xxxx_4_True_CVCV_93',
#  'XXX_3_True_CCC_16 xxxx_4_True_CVVC_5',
#  'XXX_3_True_CCC_16 xxxx_5_True_VCCVC_98',
#  'XXX_3_True_CCC_16 xxxx_5_True_VCVVC_190',
#  'XXX_3_True_CCC_16 xxxx_6_True_CVCVCV_1',
#  'XXX_3_True_CCC_16 xxxx_7_True_CVCVCVC_2',
#  'XXX_3_True_CCC_2',
#  'XXX_3_True_CCC_2 X_1_True_C_2235',
#  'XXX_3_True_CCC_2 Xxxxx_5_True_CCVVC_1',
#  'XXX_3_True_CCC_2 d',
#  'XXX_3_True_CCC_2 xxx_3_True_CVC_1040',
#  'XXX_3_True_CCC_2 xxx_3_True_CVC_294',
#  'XXX_3_True_CCC_2 xxx_3_True_CVC_4',
#  'XXX_3_True_CCC_2 xxx_3_True_VCC_3169',
#  'XXX_3_True_CCC_2 xxxx',
#  'XXX_3_True_CCC_2 xxxx_4_True_CCVC_224',
#  'XXX_3_True_CCC_2 xxxx_5_True_CVVVC_1',
#  'XXX_3_True_CCC_2 xxxx_6_True_CVCCVC_7',
#  'XXX_3_True_CCC_2 xxxx_9_True_VCCVCVVCC_5',
#  'XXX_3_True_CCC_3',
#  'XXX_3_True_CCC_3 XXXX_4_True_CCCC_1',
#  'XXX_3_True_CCC_3 XXX_3_True_CCC_1',
#  'XXX_3_True_CCC_3 XXX_3_True_CCC_13',
#  'XXX_3_True_CCC_3 XX_2_True_CC_1',
#  'XXX_3_True_CCC_3 XX_2_True_CC_5',
#  'XXX_3_True_CCC_3 _1_False_C_1',
#  'XXX_3_True_CCC_3 _1_False_C_12',
#  'XXX_3_True_CCC_3 _1_False_C_16',
#  'XXX_3_True_CCC_3 _1_False_C_9',
#  'XXX_3_True_CCC_3 xx_2_True_VC_1049',
#  'XXX_3_True_CCC_3 xx_2_True_VC_1297',
#  'XXX_3_True_CCC_3 xx_2_True_VC_828',
#  'XXX_3_True_CCC_3 xxx_3_True_CVC_6',
#  'XXX_3_True_CCC_3 xxxx_5_True_CVCVC_12',
#  'XXX_3_True_CCC_3 xxxx_5_True_CVCVC_7',
#  'XXX_3_True_CCC_3 xxxx_7_True_VCVCVCC_64',
#  'XXX_3_True_CCC_4',
#  'XXX_3_True_CCC_4 XXXX_5_True_CCCCC_1',
#  'XXX_3_True_CCC_4 X_1_True_C_2235',
#  'XXX_3_True_CCC_4 _1_False_C_9',
#  'XXX_3_True_CCC_4 _1_False__0',
#  'XXX_3_True_CCC_4 xx_2_True_VC_1049',
#  'XXX_3_True_CCC_4 xx_2_True_VC_1297',
#  'XXX_3_True_CCC_4 xx_2_True_VC_1365',
#  'XXX_3_True_CCC_4 xx_2_True_VC_393',
#  'XXX_3_True_CCC_4 xxx_3_True_VCC_3169',
#  'XXX_3_True_CCC_4 xxxx_5_True_CVCVC_6',
#  'XXX_3_True_CCC_4 xxxx_5_True_CVCVC_64',
#  'XXX_3_True_CCC_4 xxxx_6_True_CCVCCC_0',
#  'XXX_3_True_CCC_4 xxxx_6_True_CVCCCV_10',
#  'XXX_3_True_CCC_4 xxxx_7_True_CVCVVCV_156',
#  'XXX_3_True_CCC_4 xxxx_8_True_CVCVCVVC_47',
#  'XXX_3_True_CCC_4 xxxx_8_True_VCCCVCCV_8',
#  'XXX_3_True_CCC_5',
#  'XXX_3_True_CCC_5 XXXX_6_True_CCCCCC_1',
#  'XXX_3_True_CCC_5 X_1_True_C_2235',
#  'XXX_3_True_CCC_5 Xxxxx_5_True_CCVCC_4',
#  'XXX_3_True_CCC_5 Xxxxx_8_True_CVCCVVCC_1',
#  'XXX_3_True_CCC_5 _1_False_C_16',
#  'XXX_3_True_CCC_5 _1_False_C_163',
#  'XXX_3_True_CCC_5 xxx_3_True_CCV_4090',
#  'XXX_3_True_CCC_5 xxxx_4_True_CVCV_20',
#  'XXX_3_True_CCC_5 xxxx_5_True_CVCVC_0',
#  'XXX_3_True_CCC_5 xxxx_8_True_VCCVCVCV_1',
#  'XXX_3_True_CCC_5 xxxx_9_True_CVCCVCVCV_4',
#  'XXX_3_True_CCC_8',
#  'XXX_3_True_CCC_8 XXXX_4_True_CCCC_2',
#  'XXX_3_True_CCC_8 XXXX_8_True_CCCCCCCC_1',
#  'XXX_3_True_CCC_8 XX_2_True_CC_8',
#  'XXX_3_True_CCC_8 X_1_True_C_2235',
#  'XXX_3_True_CCC_8 _1_False_C_16',
#  'XXX_3_True_CCC_8 xx_2_True_VC_596',
#  'XXX_3_True_CCC_8 xxx_3_True_CCV_4090',
#  'XXX_3_True_CCC_8 xxxx_5_True_CVCVC_58',
#  'XXX_3_True_CCC_8 xxxx_8_True_VCVCVCVC_12',
#  'XXX_3_True_CCC_9',
#  'XXX_3_True_CCC_9 _1_False_C_16',
#  'XXX_3_True_CCC_9 _1_False_C_9',
#  'XXX_3_True_CCC_9 xxxx_10_True_CVCCVVCVCC_124',
#  'XXX_3_True_CCC_9 xxxx_4_True_CVCC_709',
#  'XXX_3_True_CCC_9 xxxx_5_True_CVVCV_52',
#  'XXX_3_True_CCC_9 xxxx_5_True_VCCVC_19',
#  'XXX_3_True_CCC_9 xxxx_6_True_CCCVCC_29',
#  'XXX_3_True_CCC_9 xxxx_6_True_CVCCVC_10',
#  'XXX_3_True_CCC_9 xxxx_7_True_CCVCCVC_92',
#  'XXX_4_False_CCCC_1',
#  'XXX_4_False_CCCC_1 XXXX_8_True_CCCCCCCC_1',
#  'XXX_9_False_CVCCCCCCC_0',
#  'XXX_9_False_CVCCCCCCC_0 _1_False_C_9',
#  'XXXx_4_True_CCCC_1',
#  'XXXx_4_True_CCCC_1 XXXX_5_True_CCCCC_0',
#  'XXXxxxx_8_True_CCCCVCVC_1',
#  'XXXxxxx_8_True_CCCCVCVC_1 _1_False_C_5',
#  'XX_10_False_CVCCVVCCCC_1',
#  'XX_10_False_CVCCVVCCCC_1 X_1_True_C_2235',
#  'XX_2_True_CC_0',
#  'XX_2_True_CC_0 _1_False_C_1',
#  'XX_2_True_CC_0 _1_False_C_12',
#  'XX_2_True_CC_0 _1_False_C_16',
#  'XX_2_True_CC_0 _1_False_C_4',
#  'XX_2_True_CC_0 _1_False_C_9',
#  'XX_2_True_CC_0 x_2_False_CC_0',
#  'XX_2_True_CC_1',
#  'XX_2_True_CC_1 XXXX',
#  'XX_2_True_CC_1 XXXX_4_True_CCCC_0',
#  'XX_2_True_CC_1 XXXX_6_True_CCCCCC_1',
#  'XX_2_True_CC_1 XX_2_True_CC_3',
#  'XX_2_True_CC_1 Xxxxx_5_True_CCCVC_8',
#  'XX_2_True_CC_1 Xxxxx_5_True_CCVVC_3',
#  'XX_2_True_CC_1 Xxxxx_5_True_CCVVC_4',
#  'XX_2_True_CC_1 _1_False_C_1',
#  'XX_2_True_CC_1 _1_False_C_12',
#  'XX_2_True_CC_1 _1_False_C_16',
#  'XX_2_True_CC_1 _1_False_C_9',
#  'XX_2_True_CC_1 x_2_False_CC_0',
#  'XX_2_True_CC_1 xx_2_True_CV_2078',
#  'XX_2_True_CC_1 xx_2_True_VC_1049',
#  'XX_2_True_CC_1 xx_2_True_VC_1365',
#  'XX_2_True_CC_1 xx_2_True_VC_231',
#  'XX_2_True_CC_1 xx_2_True_VC_393',
#  'XX_2_True_CC_1 xx_2_True_VC_828',
#  'XX_2_True_CC_1 xxx_3_True_CVC_162',
#  'XX_2_True_CC_1 xxx_3_True_CVC_1859',
#  'XX_2_True_CC_1 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_1 xxxx_10_True_CVCVCVCVCC_103',
#  'XX_2_True_CC_1 xxxx_5_True_CVCCC_4',
#  'XX_2_True_CC_1 xxxx_6_True_CCVVCC_2',
#  'XX_2_True_CC_1 xxxx_6_True_CVCCVC_37',
#  'XX_2_True_CC_1 xxxx_6_True_VVCVCC_33',
#  'XX_2_True_CC_1 xxxx_7_True_CVCVVCV_156',
#  'XX_2_True_CC_1 xxxx_8_True_CVCCCVCC_1',
#  'XX_2_True_CC_1 xxxx_9_True_CCVCCVCCC_3',
#  'XX_2_True_CC_2',
#  'XX_2_True_CC_2 XX_2_True_CC_1',
#  'XX_2_True_CC_2 XX_2_True_CC_8',
#  'XX_2_True_CC_2 X_1_True_C_2235',
#  'XX_2_True_CC_2 Xxxxx_6_True_CCVCCC_2',
#  'XX_2_True_CC_2 _1_False_C_1',
#  'XX_2_True_CC_2 x_2_False_CC_0',
#  'XX_2_True_CC_2 xx_2_True_VC_1049',
#  'XX_2_True_CC_2 xx_2_True_VC_231',
#  'XX_2_True_CC_2 xxx_3_True_CVC_1040',
#  'XX_2_True_CC_2 xxx_3_True_CVC_1859',
#  'XX_2_True_CC_2 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_2 xxxx',
#  'XX_2_True_CC_2 xxxx_10_True_CVCCVVCVCC_124',
#  'XX_2_True_CC_2 xxxx_4_True_CVCC_26',
#  'XX_2_True_CC_2 xxxx_4_True_CVCC_709',
#  'XX_2_True_CC_2 xxxx_5_True_CVCVC_4',
#  'XX_2_True_CC_2 xxxx_8_True_CCVCVCVC_7',
#  'XX_2_True_CC_2 xxxx_9_True_CVCVCCVCC_58',
#  'XX_2_True_CC_3',
#  'XX_2_True_CC_3 XXXX_4_True_CCCC_0',
#  'XX_2_True_CC_3 XXX_3_True_CCC_16',
#  'XX_2_True_CC_3 XXX_3_True_CCC_4',
#  'XX_2_True_CC_3 _1_False_C_9',
#  'XX_2_True_CC_3 d_1_False_C_60',
#  'XX_2_True_CC_3 xx_2_True_CV_2078',
#  'XX_2_True_CC_3 xx_2_True_VC_1297',
#  'XX_2_True_CC_3 xxx_3_True_CCV_4090',
#  'XX_2_True_CC_3 xxx_3_True_CVC_1859',
#  'XX_2_True_CC_3 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_3 xxxx_4_True_CVCC_167',
#  'XX_2_True_CC_3 xxxx_4_True_CVCC_72',
#  'XX_2_True_CC_4',
#  'XX_2_True_CC_4 XXXX_5_True_CCCCC_1',
#  'XX_2_True_CC_4 XXXX_9_True_CCCCCCCCC_1',
#  'XX_2_True_CC_4 XXX_3_True_CCC_3',
#  'XX_2_True_CC_4 Xxxxx_5_True_CVVCC_1',
#  'XX_2_True_CC_4 _1_False_C_1',
#  'XX_2_True_CC_4 _1_False_C_12',
#  'XX_2_True_CC_4 _1_False_C_163',
#  'XX_2_True_CC_4 _1_False_C_9',
#  'XX_2_True_CC_4 xx_2_True_CC_158',
#  'XX_2_True_CC_4 xx_2_True_VC_1297',
#  'XX_2_True_CC_4 xx_2_True_VC_487',
#  'XX_2_True_CC_4 xxx_3_True_CVC_1040',
#  'XX_2_True_CC_4 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_4 xxxx_4_True_CCVC_2',
#  'XX_2_True_CC_4 xxxx_4_True_CVVC_329',
#  'XX_2_True_CC_4 xxxx_4_True_VCVV_8',
#  'XX_2_True_CC_4 xxxx_5_True_CCVCC_188',
#  'XX_2_True_CC_4 xxxx_8_True_CVCCVVCC_2',
#  'XX_2_True_CC_5',
#  'XX_2_True_CC_5 XXXX',
#  'XX_2_True_CC_5 XXXX_6_True_CCCCCC_0',
#  'XX_2_True_CC_5 XXXX_7_True_CCCCCCC_1',
#  'XX_2_True_CC_5 XXXX_8_True_CCCCCCCC_0',
#  'XX_2_True_CC_5 XXX_3_True_CCC_16',
#  'XX_2_True_CC_5 xxx_3_True_CVC_1859',
#  'XX_2_True_CC_6',
#  'XX_2_True_CC_6 XX_2_True_CC_1',
#  'XX_2_True_CC_6 xx_2_True_VC_1297',
#  'XX_2_True_CC_6 xxxx_5_True_CCCCV_24',
#  'XX_2_True_CC_6 xxxx_5_True_CCCVC_18',
#  'XX_2_True_CC_7',
#  'XX_2_True_CC_7 XXXX_6_True_CCCCCC_1',
#  'XX_2_True_CC_7 _1_False_C_9',
#  'XX_2_True_CC_7 xxx_3_True_CVC_1859',
#  'XX_2_True_CC_7 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_7 xxxx_4_True_CCVC_627',
#  'XX_2_True_CC_7 xxxx_7_True_CCVCVCC_10',
#  'XX_2_True_CC_7 xxxx_9_True_CVCVCVCCC_1',
#  'XX_2_True_CC_8',
#  'XX_2_True_CC_8 XXXX_4_True_CCCC_1',
#  'XX_2_True_CC_8 XXXX_4_True_CCCC_2',
#  'XX_2_True_CC_8 XXXX_5_True_CCCCC_0',
#  'XX_2_True_CC_8 XXXX_6_True_CCCCCC_0',
#  'XX_2_True_CC_8 XXX_3_True_CCC_1',
#  'XX_2_True_CC_8 XXX_3_True_CCC_3',
#  'XX_2_True_CC_8 _1_False_C_16',
#  'XX_2_True_CC_8 _1_False_C_9',
#  'XX_2_True_CC_8 xx_2_True_VC_195',
#  'XX_2_True_CC_8 xxx_3_True_CVC_701',
#  'XX_2_True_CC_8 xxx_3_True_VCC_3169',
#  'XX_2_True_CC_8 xxxx_10_True_VCCVCVVCCV_60',
#  'XX_2_True_CC_8 xxxx_4_True_CVCC_86',
#  'XX_2_True_CC_8 xxxx_5_True_CVCCV_62',
#  'XX_2_True_CC_8 xxxx_7_True_CVCCVCV_215',
#  'XX_2_True_CC_9',
#  'XX_2_True_CC_9 _1_False_C_16',
#  'XX_2_True_CC_9 _1_False_C_9',
#  'XX_2_True_CC_9 _2_False_CC_0',
#  'XX_2_True_CC_9 xx_2_True_VC_596',
#  'XX_2_True_CC_9 xxx_3_True_CVC_162',
#  'XX_2_True_CC_9 xxxx_10_True_CVCCVVCVCC_124',
#  'XX_2_True_CC_9 xxxx_5_True_CCVCC_0',
#  'XX_2_True_CC_9 xxxx_5_True_CCVCV_41',
#  'XX_2_True_CC_9 xxxx_5_True_CVCCC_13',
#  'XX_2_True_CC_9 xxxx_6_True_CCVCVC_6',
#  'XX_2_True_CC_9 xxxx_9_True_CVCCVCVCC_3',
#  'XX_8_False_CVCVCCCC_1',
#  'XX_8_False_CVCVCCCC_1 _1_False_C_163',
#  'XX_8_False_CVCVCCCC_1 xx_2_True_VC_1297',
#  'XX_9_False_CCVVCCCCC_0',
#  'XX_9_False_CCVVCCCCC_0 Xxxx_4_True_CVCV_1',
#  'XX_9_False_CVCVCCCCC_1',
#  'XX_9_False_CVCVCCCCC_1 XXX_3_True_CCC_0',
#  'XXx_3_True_CCC_0',
#  'XXx_3_True_CCC_0 _1_False_C_16',
#  'XXx_3_True_CCC_0 xxxx_7_True_CCVCVCC_1',
#  'XXx_3_True_CCC_1',
#  'XXx_3_True_CCC_1 _1_False_C_9',
#  'XXx_3_True_CCC_1 xxx_3_True_VCV_479',
#  'XXx_3_True_CCC_1 xxxx_4_True_CCVC_627',
#  'XXx_3_True_CCV_0',
#  'XXx_3_True_CCV_0 x_2_False_CC_0',
#  'XXxx_4_True_CCCC_1',
#  'XXxx_4_True_CCCC_1 xx_2_True_CV_366',
#  'XXxx_4_True_CCVC_0',
#  'XXxx_4_True_CCVC_0 _3_False_CCC_14',
#  'XXxx_4_True_CCVC_1',
#  'XXxx_4_True_CCVC_1 xx_2_True_CV_440',
#  'XXxxx_5_True_CCCVC_0',
#  'XXxxx_5_True_CCCVC_0 _1_False_C_9',
#  'XXxxx_5_True_CCVCC_1',
#  'XXxxx_5_True_CCVCC_1 xx_2_True_VC_1049',
#  'XXxxx_5_True_CCVCC_1 xxxx_4_True_CCVC_200',
#  'X_10_False_CCCCCCCCCC_1',
#  'X_10_False_CCCCCCCCCC_1 xx_2_True_VC_63',
#  'X_10_False_CCCVCCCCCC_1',
#  'X_10_False_CCCVCCCCCC_1 xxx_3_True_CVC_1859',
#  'X_10_False_CCVCVCCCCC_1',
#  'X_10_False_CCVCVCCCCC_1 xxxx_6_True_CVVVCC_3',
#  'X_10_False_CVCCCCCCCC_1',
#  'X_10_False_CVCCCCCCCC_1 xxxx_6_True_CVVCCC_224',
#  'X_10_False_CVCCVCCCCC_1',
#  'X_10_False_CVCCVCCCCC_1 xxxx_4_True_CVCV_148',
#  'X_10_False_CVCCVCCCCC_1 xxxx_7_True_CVCVCVC_6',
#  'X_10_False_CVCCVCVCCC_1',
#  'X_10_False_CVCCVCVCCC_1 xxxx_4_True_CVCC_123',
#  'X_10_False_CVCVCCCCCC_1',
#  'X_10_False_CVCVCCCCCC_1 xxxx_4_True_CVCV_67',
#  'X_10_False_CVCVCVCCCC_1',
#  'X_10_False_CVCVCVCCCC_1 xxxx_4_True_CVCV_148',
#  'X_10_False_VCCVCVCCCC_1',
#  'X_10_False_VCCVCVCCCC_1 xx_2_True_VC_63',
#  'X_10_False_VCVCVCCCCC_1',
#  'X_10_False_VCVCVCCCCC_1 xxxx_4_True_CVCC_294',
#  'X_11_False_CCVCCVCCCCC_1',
#  'X_11_False_CCVCCVCCCCC_1 xxxx_5_True_CCVVC_71',
#  'X_11_False_CCVCCVCVCCC_1',
#  'X_11_False_CCVCCVCVCCC_1 xxxx_6_True_CVVCCC_224',
#  'X_11_False_CCVVCCCCCCC_1',
#  'X_11_False_CCVVCCCCCCC_1 xxxx_8_True_CCVCVVCC_4',
#  'X_11_False_CVCVCVCVCCC_1',
#  'X_11_False_CVCVCVCVCCC_1 xxxx_4_True_CVCC_294',
#  'X_11_False_CVCVVCVCCCC_1',
#  'X_11_False_CVCVVCVCCCC_1 d_1_False_C_60',
#  'X_11_False_VCCVCCVCCCC_1',
#  'X_11_False_VCCVCCVCCCC_1 xxx_3_True_CVC_172',
#  'X_11_False_VCCVVCCVCCC_1',
#  'X_11_False_VCCVVCCVCCC_1 xxxx_8_True_CCVCVVVC_9',
#  'X_12_False_CCVCCVCCCCCC_1',
#  'X_12_False_CCVCCVCCCCCC_1 xxx_3_True_CVC_162',
#  'X_12_False_CCVCVCCCCCCC_1',
#  'X_12_False_CCVCVCCCCCCC_1 xxxx_4_True_CVCV_538',
#  'X_12_False_CVCCCVVCCCCC_1',
#  'X_12_False_CVCCCVVCCCCC_1 xx_2_True_CV_2',
#  'X_12_False_CVCCVCCVCCCC_1',
#  'X_12_False_CVCCVCCVCCCC_1 xxxx_4_True_CVCV_114',
#  'X_12_False_CVCVCCVCCCCC_1',
#  'X_12_False_CVCVCCVCCCCC_1 xxxx_4_True_CVCV_538',
#  'X_13_False_CCCVCVCCCCCCC_1',
#  'X_13_False_CCCVCVCCCCCCC_1 xxxx_7_True_CCVVCCC_35',
#  'X_13_False_CVCCVVCVCCCCC_1',
#  'X_13_False_CVCCVVCVCCCCC_1 xxxx_4_True_VCVC_27',
#  'X_13_False_VCCCVCVCCVCCC_1',
#  'X_13_False_VCCCVCVCCVCCC_1 xxxx_5_True_CCVVC_260',
#  'X_13_False_VCCVCVVCCVCCC_1',
#  'X_13_False_VCCVCVVCCVCCC_1 xxxx_4_True_CVCV_538',
#  'X_14_False_CVCCVCCCVCCCCC_1',
#  'X_14_False_CVCCVCCCVCCCCC_1 xx_2_True_VC_63',
#  'X_14_False_CVCVCCVCCVCCCC_1',
#  'X_14_False_CVCVCCVCCVCCCC_1 xxxx_10_True_CVCVCVCVVC_4',
#  'X_14_False_CVCVCCVCCVCCCC_1 xxxx_4_True_CVCC_379',
#  'X_14_False_CVCVCCVCCVCCCC_1 xxxx_4_True_CVCV_148',
#  'X_15_False_CCVCCVCCVCCVCCC_1',
#  'X_15_False_CCVCCVCCVCCVCCC_1 xxx_3_True_CVC_91',
#  'X_15_False_CVCCCVCCVVCCCCC_1',
#  'X_15_False_CVCCCVCCVVCCCCC_1 xxxx_4_True_VCVC_27',
#  'X_1_True_C_0',
#  'X_1_True_C_0 _1_False_C_3',
#  'X_1_True_C_0 x_2_False_CC_0',
#  'X_1_True_C_1',
#  'X_1_True_C_1 X_1_True_C_2235',
#  'X_1_True_C_1 Xxx_3_True_CVC_10',
#  'X_1_True_C_1 Xxxxx_6_True_CVCVCC_1',
#  'X_1_True_C_1 _1_False_C_163',
#  'X_1_True_C_1 xxx_3_True_CVC_1859',
#  'X_1_True_C_1 xxx_3_True_VCC_3169',
#  'X_1_True_C_1 xxxx_4_True_CVCV_538',
#  'X_1_True_C_2235',
#  'X_1_True_C_2235 XXX',
#  'X_1_True_C_2235 XXXX_4_True_CCCC_1',
#  'X_1_True_C_2235 XXXX_4_True_CCCC_10',
#  'X_1_True_C_2235 XXXX_4_True_CCCC_2',
#  'X_1_True_C_2235 XXXX_4_True_CCCC_3',
#  'X_1_True_C_2235 XXXX_5_True_CCCCC_1',
#  'X_1_True_C_2235 XXXX_5_True_CCCCC_4',
#  'X_1_True_C_2235 XXXX_6_True_CCCCCC_1',
#  'X_1_True_C_2235 XXX_3_True_CCC_1',
#  'X_1_True_C_2235 Xxxx_4_True_CCVC_1',
#  'X_1_True_C_2235 Xxxx_4_True_CVCC_17',
#  'X_1_True_C_2235 Xxxx_4_True_CVCC_2',
#  'X_1_True_C_2235 Xxxx_4_True_CVCV_29',
#  'X_1_True_C_2235 Xxxxx_7_True_CCCVCVC_1',
#  'X_1_True_C_2235 _1_False_C_0',
#  'X_1_True_C_2235 _1_False_C_16',
#  'X_1_True_C_2235 _1_False__0',
#  'X_1_True_C_2235 x_1_True_C_3',
#  'X_1_True_C_2235 x_1_True_C_4',
#  'X_1_True_C_2235 x_1_True_C_6',
#  'X_1_True_C_2235 x_1_True_C_8',
#  'X_1_True_C_2235 x_1_True_V_12',
#  'X_1_True_C_2235 x_1_True_V_2405',
#  'X_1_True_C_2235 x_2_False_CC_0',
#  'X_1_True_C_2235 xx_2_True_CC_4',
#  'X_1_True_C_2235 xx_2_True_CV_0',
#  'X_1_True_C_2235 xx_2_True_CV_1',
#  'X_1_True_C_2235 xx_2_True_CV_2',
#  'X_1_True_C_2235 xx_2_True_CV_207',
#  'X_1_True_C_2235 xx_2_True_CV_83',
#  'X_1_True_C_2235 xx_2_True_VC_596',
#  'X_1_True_C_2235 xx_2_True_VC_63',
#  'X_1_True_C_2235 xx_3_False_CCC_1',
#  'X_1_True_C_2235 xx_3_False_CCV_0',
#  'X_1_True_C_2235 xxx',
#  'X_1_True_C_2235 xxx_3_True_CCV_4090',

#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_15',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_49',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_6',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_7',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_8',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCC_9',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCV_1',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCV_4',
#  'X_1_True_C_2235 xxxx_6_True_CVCVCV_5',
#  'X_1_True_C_2235 xxxx_6_True_CVCVVC_1',
#  'X_1_True_C_2235 xxxx_6_True_CVVCCC_15',
#  'X_1_True_C_2235 xxxx_6_True_CVVCCC_224',
#  'X_1_True_C_2235 xxxx_6_True_CVVCVC_10',
#  'X_1_True_C_2235 xxxx_6_True_CVVCVC_23',
#  'X_1_True_C_2235 xxxx_6_True_CVVCVC_35',
#  'X_1_True_C_2235 xxxx_6_True_VCCVCC_129',
#  'X_1_True_C_2235 xxxx_6_True_VCCVCC_22',
#  'X_1_True_C_2235 xxxx_6_True_VCCVCC_36',
#  'X_1_True_C_2235 xxxx_6_True_VCCVCV_1',
#  'X_1_True_C_2235 xxxx_6_True_VVCCVC_9',
#  'X_1_True_C_2235 xxxx_7_True_CCVCCVC_1',
#  'X_1_True_C_2235 xxxx_7_True_CCVCCVC_10',
#  'X_1_True_C_2235 xxxx_7_True_CCVCCVC_19',
#  'X_1_True_C_2235 xxxx_7_True_CCVCCVC_2',
#  'X_1_True_C_2235 xxxx_7_True_CCVCCVC_31',
#  'X_1_True_C_2235 xxxx_7_True_CCVVCCC_24',
#  'X_1_True_C_2235 xxxx_7_True_CCVVCCC_35',
#  'X_1_True_C_2235 xxxx_7_True_CVCCCVC_3',
#  'X_1_True_C_2235 xxxx_7_True_CVCCCVC_4',
#  'X_1_True_C_2235 xxxx_7_True_CVCCVCC_0',
#  'X_1_True_C_2235 xxxx_7_True_CVCCVCC_14',
#  'X_1_True_C_2235 xxxx_7_True_CVCCVCV_4',
#  'X_1_True_C_2235 xxxx_7_True_CVCCVVC_5',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCCC_18',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCCC_21',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCVC_15',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCVC_2',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCVC_5',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCVC_50',
#  'X_1_True_C_2235 xxxx_7_True_CVCVCVC_6',
#  'X_1_True_C_2235 xxxx_7_True_CVCVVCV_0',
#  'X_1_True_C_2235 xxxx_7_True_CVCVVCV_12',
#  'X_1_True_C_2235 xxxx_7_True_VCCCVVC_4',
#  'X_1_True_C_2235 xxxx_7_True_VCCVCVC_1',
#  'X_1_True_C_2235 xxxx_7_True_VCCVCVC_137',
#  'X_1_True_C_2235 xxxx_7_True_VCCVCVC_20',
#  'X_1_True_C_2235 xxxx_7_True_VCCVCVC_43',
#  'X_1_True_C_2235 xxxx_7_True_VCCVVCC_14',
#  'X_1_True_C_2235 xxxx_7_True_VCVCVCC_15',
#  'X_1_True_C_2235 xxxx_7_True_VCVVCCC_33',
#  'X_1_True_C_2235 xxxx_8_True_CCCVCCCC_3',
#  'X_1_True_C_2235 xxxx_8_True_CCCVVCVC_1',
#  'X_1_True_C_2235 xxxx_8_True_CCVCVCCC_38',
#  'X_1_True_C_2235 xxxx_8_True_CCVCVVCC_4',
#  'X_1_True_C_2235 xxxx_8_True_CVCCVCCC_7',
#  'X_1_True_C_2235 xxxx_8_True_CVCCVCVC_1',
#  'X_1_True_C_2235 xxxx_8_True_CVCCVCVC_2',
#  ...]

# %% [markdown]
# ## Neural Experiments
