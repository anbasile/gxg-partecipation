# %%
import numpy as np
import pandas as pd
import xmltodict
import glob
import re
from os.path import basename, splitext

# %%
data_dir = glob.glob('../../Data/Training/*')
df = {}

# %%
for genre_file in data_dir:
    with open(genre_file) as f:
        tmp = f.read().split('</doc>')
        name = splitext(basename(genre_file))[0]
        df[name] = tmp
        del tmp

# %%
tmp = []
for name, corpus in df.items():
    i = 0
    for item in corpus:
        m = re.search('<doc id="[0-9]+" genre="[a-zA-Z]+" gender="[M|F]">', item)
        if m is not None:
            i += 1
            tmp.append((m.group(0), item))
    assert i==len(corpus)-1
del df
df = pd.DataFrame(tmp)

# %%
df.rename(columns={0:'meta', 1:'text'}, inplace=True)
df['gender'] = df.iloc[:,0].str.extract('(gender=".")')
df['genre'] = df.iloc[:,0].str.extract('(genre="[a-zA-Z]+")')
df['docid'] = df.iloc[:,0].str.extract('(id="[0-9]+")')
df.sample(5)
# Out:
#                                               meta  \
# 7761    <doc id="2785" genre="twitter" gender="F">
# 7709    <doc id="5367" genre="twitter" gender="F">
# 2247     <doc id="839" genre="youtube" gender="M">
# 10860  <doc id="61" genre="journalism" gender="M">
# 2895    <doc id="4815" genre="youtube" gender="M">
#
#                                                     text      gender  \
# 7761   \n<doc id="2785" genre="twitter" gender="F">\n...  gender="F"
# 7709   \n<doc id="5367" genre="twitter" gender="F">\n...  gender="F"
# 2247   \n<doc id="839" genre="youtube" gender="M">\nF...  gender="M"
# 10860  \n<doc id="61" genre="journalism" gender="M">\...  gender="M"
# 2895   \n<doc id="4815" genre="youtube" gender="M">\n...  gender="M"
#
#                     genre      docid
# 7761      genre="twitter"  id="2785"
# 7709      genre="twitter"  id="5367"
# 2247      genre="youtube"   id="839"
# 10860  genre="journalism"    id="61"
# 2895      genre="youtube"  id="4815"

# %%
for idx, row in df.iterrows():
    row.text = row.text.replace(row.meta, '').strip()

# %%
df.to_json('../../Data/gxg.json', orient='records', lines=True)

# %%
pd.read_json('../../Data/gxg.json', lines=True)
# Out:
#           docid      gender               genre  \
# 0        id="1"  gender="M"       genre="diary"
# 1        id="2"  gender="M"       genre="diary"
# 2        id="3"  gender="M"       genre="diary"
# 3        id="4"  gender="M"       genre="diary"
# 4        id="5"  gender="M"       genre="diary"
# 5        id="6"  gender="M"       genre="diary"
# 6        id="7"  gender="M"       genre="diary"
# 7        id="8"  gender="M"       genre="diary"
# 8        id="9"  gender="M"       genre="diary"
# 9       id="10"  gender="M"       genre="diary"
# 10      id="11"  gender="M"       genre="diary"
# 11      id="12"  gender="M"       genre="diary"
# 12      id="13"  gender="M"       genre="diary"
# 13      id="14"  gender="M"       genre="diary"
# 14      id="15"  gender="M"       genre="diary"
# 15      id="16"  gender="M"       genre="diary"
# 16      id="17"  gender="M"       genre="diary"
# 17      id="18"  gender="M"       genre="diary"
# 18      id="19"  gender="M"       genre="diary"
# 19      id="20"  gender="M"       genre="diary"
# 20      id="21"  gender="M"       genre="diary"
# 21      id="22"  gender="M"       genre="diary"
# 22      id="23"  gender="M"       genre="diary"
# 23      id="24"  gender="M"       genre="diary"
# 24      id="25"  gender="M"       genre="diary"
# 25      id="26"  gender="M"       genre="diary"
# 26      id="27"  gender="M"       genre="diary"
# 27      id="28"  gender="M"       genre="diary"
# 28      id="29"  gender="M"       genre="diary"
# 29      id="30"  gender="M"       genre="diary"
# ...         ...         ...                 ...
# 10970  id="171"  gender="F"  genre="journalism"
# 10971  id="172"  gender="F"  genre="journalism"
# 10972  id="173"  gender="F"  genre="journalism"
# 10973  id="174"  gender="F"  genre="journalism"
# 10974  id="175"  gender="F"  genre="journalism"
# 10975  id="176"  gender="F"  genre="journalism"
# 10976  id="177"  gender="F"  genre="journalism"
# 10977  id="178"  gender="F"  genre="journalism"
# 10978  id="179"  gender="F"  genre="journalism"
# 10979  id="180"  gender="F"  genre="journalism"
# 10980  id="181"  gender="F"  genre="journalism"
# 10981  id="182"  gender="F"  genre="journalism"
# 10982  id="183"  gender="F"  genre="journalism"
# 10983  id="184"  gender="F"  genre="journalism"
# 10984  id="185"  gender="F"  genre="journalism"
# 10985  id="186"  gender="F"  genre="journalism"
# 10986  id="187"  gender="F"  genre="journalism"
# 10987  id="188"  gender="F"  genre="journalism"
# 10988  id="189"  gender="F"  genre="journalism"
# 10989  id="190"  gender="F"  genre="journalism"
# 10990  id="191"  gender="F"  genre="journalism"
# 10991  id="192"  gender="F"  genre="journalism"
# 10992  id="193"  gender="F"  genre="journalism"
# 10993  id="194"  gender="F"  genre="journalism"
# 10994  id="195"  gender="F"  genre="journalism"
# 10995  id="196"  gender="F"  genre="journalism"
# 10996  id="197"  gender="F"  genre="journalism"
# 10997  id="198"  gender="F"  genre="journalism"
# 10998  id="199"  gender="F"  genre="journalism"
# 10999  id="200"  gender="F"  genre="journalism"
#
#                                                meta  \
# 0             <doc id="1" genre="diary" gender="M">
# 1             <doc id="2" genre="diary" gender="M">
# 2             <doc id="3" genre="diary" gender="M">
# 3             <doc id="4" genre="diary" gender="M">
# 4             <doc id="5" genre="diary" gender="M">
# 5             <doc id="6" genre="diary" gender="M">
# 6             <doc id="7" genre="diary" gender="M">
# 7             <doc id="8" genre="diary" gender="M">
# 8             <doc id="9" genre="diary" gender="M">
# 9            <doc id="10" genre="diary" gender="M">
# 10           <doc id="11" genre="diary" gender="M">
# 11           <doc id="12" genre="diary" gender="M">
# 12           <doc id="13" genre="diary" gender="M">
# 13           <doc id="14" genre="diary" gender="M">
# 14           <doc id="15" genre="diary" gender="M">
# 15           <doc id="16" genre="diary" gender="M">
# 16           <doc id="17" genre="diary" gender="M">
# 17           <doc id="18" genre="diary" gender="M">
# 18           <doc id="19" genre="diary" gender="M">
# 19           <doc id="20" genre="diary" gender="M">
# 20           <doc id="21" genre="diary" gender="M">
# 21           <doc id="22" genre="diary" gender="M">
# 22           <doc id="23" genre="diary" gender="M">
# 23           <doc id="24" genre="diary" gender="M">
# 24           <doc id="25" genre="diary" gender="M">
# 25           <doc id="26" genre="diary" gender="M">
# 26           <doc id="27" genre="diary" gender="M">
# 27           <doc id="28" genre="diary" gender="M">
# 28           <doc id="29" genre="diary" gender="M">
# 29           <doc id="30" genre="diary" gender="M">
# ...                                             ...
# 10970  <doc id="171" genre="journalism" gender="F">
# 10971  <doc id="172" genre="journalism" gender="F">
# 10972  <doc id="173" genre="journalism" gender="F">
# 10973  <doc id="174" genre="journalism" gender="F">
# 10974  <doc id="175" genre="journalism" gender="F">
# 10975  <doc id="176" genre="journalism" gender="F">
# 10976  <doc id="177" genre="journalism" gender="F">
# 10977  <doc id="178" genre="journalism" gender="F">
# 10978  <doc id="179" genre="journalism" gender="F">
# 10979  <doc id="180" genre="journalism" gender="F">
# 10980  <doc id="181" genre="journalism" gender="F">
# 10981  <doc id="182" genre="journalism" gender="F">
# 10982  <doc id="183" genre="journalism" gender="F">
# 10983  <doc id="184" genre="journalism" gender="F">
# 10984  <doc id="185" genre="journalism" gender="F">
# 10985  <doc id="186" genre="journalism" gender="F">
# 10986  <doc id="187" genre="journalism" gender="F">
# 10987  <doc id="188" genre="journalism" gender="F">
# 10988  <doc id="189" genre="journalism" gender="F">
# 10989  <doc id="190" genre="journalism" gender="F">
# 10990  <doc id="191" genre="journalism" gender="F">
# 10991  <doc id="192" genre="journalism" gender="F">
# 10992  <doc id="193" genre="journalism" gender="F">
# 10993  <doc id="194" genre="journalism" gender="F">
# 10994  <doc id="195" genre="journalism" gender="F">
# 10995  <doc id="196" genre="journalism" gender="F">
# 10996  <doc id="197" genre="journalism" gender="F">
# 10997  <doc id="198" genre="journalism" gender="F">
# 10998  <doc id="199" genre="journalism" gender="F">
# 10999  <doc id="200" genre="journalism" gender="F">
#
#                                                     text
# 0      \n“Nonno mi racconti di quando”... Sara, la mi...
# 1      Il Colportaggio\nAppena ci fummo sistemati nel...
# 2      Ministerio Svizzero- Basilese\nIl mio minister...
# 3      Ministerio Zurighese\nArrivammo a Zurigo e ci ...
# 4      Ministerio Abruzzese\nVilla S. Sebastiano è un...
# 5      Era la fine di ottobre, faceva già freddo, mia...
# 6      Siamo partiti da Siena il giorno 20 maggio del...
# 7      La passeggiata della Camilluccia compiuta attr...
# 8      Vacanza per il primo anniversario della dichia...
# 9      La morte di un piccione\nIeri, lunedì 18, vers...
# 10     Tre fiori di malvarosa\nBollettino delle piant...
# 11     12 Febbraio 1940 \nQuesto diario mi è stato co...
# 12     15 Febbraio 1940 (giovedì)\nSono andato a lezi...
# 13     Sirone in questo paese nel 1890 non cera l'asi...
